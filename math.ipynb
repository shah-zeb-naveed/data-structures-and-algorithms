# %%
# log of a value vs base used

import math
import matplotlib.pyplot as plt

hs = []
x = 1000
for i in range(10, 100, 1):
    h = math.log(x, i)
    # print(h)

    hs.append(h)

plt.plot(hs)

# %%
# number of digits given max value

import math
import matplotlib.pyplot as plt

hs = []
for i in range(1, 1000, 1):
    digits = math.ceil(math.log(i, 10))
    # print(h)

    hs.append(digits)

plt.plot(hs)
